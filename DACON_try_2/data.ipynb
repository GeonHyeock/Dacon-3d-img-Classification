# %% [markdown]
# # 라이브러리

# %%
import h5py
import numpy as np
import pandas as pd

import torch
import torch.nn.functional as F
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import plotly.graph_objects as go

# %% [markdown]
# # 함수, 클래스

# %%
class GH_Dataset(torch.utils.data.Dataset): 
    def __init__(self,X,Y):
        self.x_data = torch.from_numpy(X).type(dtype=torch.float32)
        self.y_data = torch.tensor(Y).resize_(len(X),1)

    def __len__(self): 
        return len(self.x_data)
    
    def __getitem__(self, idx): 
        x = self.x_data[idx]
        y = self.y_data[idx]
        return x, y

class GH_Dataset_submission(data.Dataset):
    def __init__(self,X):
        self.x_data = torch.from_numpy(X).type(dtype=torch.float32)

    def __len__(self): 
        return len(self.x_data)
    
    def __getitem__(self, idx): 
        x = self.x_data[idx]
        return x
    
def change_data(img):
    img = np.array(img)
    M,m = np.max(img),np.min(img)
    pivot = np.linspace(m - (M-m),M + (M-m),16)
    img = np.searchsorted(pivot,img)
    result = np.zeros(shape = (16,16,16))
    for x,y,z in img:
        result[x,y,z] += 1
    return result.reshape(1,16,16,16)
    
def rotation(value):
    x,y,z = np.random.uniform(-1,1),np.random.uniform(-1,1),np.random.uniform(-1,1)
    rot_x = np.array([[
        [1,0,0],
        [0,np.cos(x),-np.sin(x)],
        [0,np.sin(x),np.cos(x)]
    ]])
    
    rot_y = np.array([[
        [np.cos(y),0,np.sin(y)],
        [0,1,0],
        [-np.sin(y),0,np.cos(y)]
    ]])
    
    rot_z = np.array([[
        [np.cos(z),-np.sin(z),0],
        [np.sin(z),np.cos(z),0],
        [0,0,1]
    ]])

    return value @ (rot_x @ rot_y @ rot_z)[0]

def data_scale(data):
    data = np.array(sorted(data, key = lambda x: [x[0],x[1],x[2]]))
    idx = np.linspace(0,data.shape[0]-1,1000).astype(int)
    return data[idx]
    
def visualize_rotate(data):
    x_eye, y_eye, z_eye = 1.25, 1.25, 0.8
    frames=[]

    def rotate_z(x, y, z, theta):
        w = x+1j*y
        return np.real(np.exp(1j*theta)*w), np.imag(np.exp(1j*theta)*w), z

    for t in np.arange(0, 10.26, 0.1):
        xe, ye, ze = rotate_z(x_eye, y_eye, z_eye, -t)
        frames.append(dict(layout=dict(scene=dict(camera=dict(eye=dict(x=xe, y=ye, z=ze))))))
    fig = go.Figure(data=data,
                    layout=go.Layout(
                        updatemenus=[dict(type='buttons',
                                    showactive=False,
                                    y=1,
                                    x=0.8,
                                    xanchor='left',
                                    yanchor='bottom',
                                    pad=dict(t=45, r=10),
                                    buttons=[dict(label='Play',
                                                    method='animate',
                                                    args=[None, dict(frame=dict(duration=50, redraw=True),
                                                                    transition=dict(duration=0),
                                                                    fromcurrent=True,
                                                                    mode='immediate'
                                                                    )]
                                                    )
                                            ]
                                    )
                                ]
                    ),
                    frames=frames
            )

    return fig

def pcshow(data):
    xs,ys,zs = data[::,0],data[::,1],data[::,2]
    data=[go.Scatter3d(x=xs, y=ys, z=zs,
                                   mode='markers')]
    fig = visualize_rotate(data)
    fig.update_traces(marker=dict(size=2,
                      line=dict(width=2,
                      color='DarkSlateGrey')),
                      selector=dict(mode='markers'))
    fig.show()

# %% [markdown]
# # 데이터 생성

# %%
path = "/home/inhamath/dacon"

train_img = h5py.File(path + '/GH_DACON_2022_08/open/train.h5','r')
train_label = pd.read_csv(path + "/GH_DACON_2022_08/open/train.csv")

train_dict = {"train_img" : [data_scale(np.unique(train_img[idx],axis=0)) for idx in train_label.ID.astype(str)],
            "train_label" : list(train_label.label)}

train_dict["train_img"] += list(map(rotation,train_dict["train_img"]))
train_dict["train_label"] += train_dict["train_label"]

dataset = GH_Dataset(np.array(train_dict["train_img"]),train_dict["train_label"])
train_dataset,test_dataset = torch.utils.data.random_split(dataset,[80000,20000])

import pickle
with open(path + '/GH_DACON_2022_08/train_dataset.pickle', 'wb') as f:
    pickle.dump(train_dataset, f)

with open(path + '/GH_DACON_2022_08/test_dataset.pickle', 'wb') as f:
    pickle.dump(test_dataset, f)

"""
test_dict = {"test_img" : [data_scale(np.unique(test_img[idx],axis=0)) for idx in test_label.ID.astype(str)]}
test_img = h5py.File(path + '/GH_DACON_2022_08/open/test.h5','r')
test_label = pd.read_csv(path + "/GH_DACON_2022_08/open/sample_submission.csv")
submission_dataset = GH_Dataset_submission(np.array(test_dict["test_img"]))

with open(path + '/GH_DACON_2022_08/submission_dataset.pickle', 'wb') as f:
    pickle.dump(submission_dataset, f)
"""
# Out:
# '\ntest_dict = {"test_img" : [data_scale(np.unique(test_img[idx],axis=0)) for idx in test_label.ID.astype(str)]}\ntest_img = h5py.File(path + \'/GH_DACON_2022_08/open/test.h5\',\'r\')\ntest_label = pd.read_csv(path + "/GH_DACON_2022_08/open/sample_submission.csv")\nsubmission_dataset = GH_Dataset_submission(np.array(test_dict["test_img"]))\n\nwith open(path + \'/GH_DACON_2022_08/submission_dataset.pickle\', \'wb\') as f:\n    pickle.dump(submission_dataset, f)\n'

# %%
path = "/home/inhamath/dacon"
import pickle
with open(path + "/GH_DACON_2022_08/train_dict.pickle", 'rb') as f:
    train_dict = pickle.load(f)

# %%
idx = 1000
data = train_dict["train_img"][idx]
print(data.shape)
print(data_scale(data).shape)
# Out:
# (17720, 3)
# (1000, 3)

# %%
print(train_dict["train_label"][idx])
pcshow(data)
# Out:
# 0
# <div>                            <div id="5de8b769-4383-410a-a967-51839ad54024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5de8b769-4383-410a-a967-51839ad54024")) {                    Plotly.newPlot(                        "5de8b769-4383-410a-a967-51839ad54024",                        [{"mode":"markers","x":[-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0 ...

# %%
pcshow(data_scale(data))
# Out:
# <div>                            <div id="e6808532-b41a-4614-a1f8-f72146e7492a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6808532-b41a-4614-a1f8-f72146e7492a")) {                    Plotly.newPlot(                        "e6808532-b41a-4614-a1f8-f72146e7492a",                        [{"mode":"markers","x":[-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.14999999999999433,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.1499999999999943,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.14999999999999428,-0.13965517241378742,-0.13965517241378742,-0.13965517241378742,-0.13965517241378742,-0.13965517241378742,-0.13965517241378742,-0.13965517241378742,-0.1396551724137874,-0.1396551724137874,-0.1396551724137874,-0.1396551724137874,-0.1396551724137874,-0.1396551724137874,-0.1396551724137874,-0.13965517 ...

# %%
pcshow(rotation(data_scale(data)))
# Out:
# <div>                            <div id="86935eb8-d7e1-40a9-aeb0-f23287b1b984" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86935eb8-d7e1-40a9-aeb0-f23287b1b984")) {                    Plotly.newPlot(                        "86935eb8-d7e1-40a9-aeb0-f23287b1b984",                        [{"mode":"markers","x":[0.1490810648237043,0.13947366888655457,0.1468721809919283,0.13356552900209168,0.09437742189324204,0.1136055510173367,0.13283368014143138,0.15206180926552607,0.14540848327060774,0.049281174899929496,0.047804139928813764,0.046327104957698075,0.039673778962779745,0.038196743991664,0.03671970902054827,0.03524267404943256,0.028589348054514255,0.02711231308339853,0.025635278112282802,0.018981952117364514,0.017504917146248737,0.01602788217513304,0.014550847204017284,0.028602685304309376,0.04783081442840407,-0.006886165751853375,0.012341963372241289,0.02639380147253338,-0.06973350689814486,-0.09191570596447096,0.0012575324639758135,-0.026100957626152936,-0.048283156692479026,-0.07046535575880